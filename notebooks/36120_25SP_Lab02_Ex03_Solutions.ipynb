# %% [markdown]
# # **Lab: Custom Python Package**

# %% [markdown]
# ## Exercise 3: Polynomial Regression
#
# This time we will perform a polynomial transformation before training a Linear Regression model.
#
#
# **Pre-requisites:**
# - Create a github account (https://github.com/join)
# - Install git (https://git-scm.com/book/en/v2/Getting-Started-Installing-Git)
# - Install pyenv (https://realpython.com/lessons/installing-pyenv/)
# - Install poetry (https://python-poetry.org/docs/#installation)
# - Install Wget for Windows users (https://eternallybored.org/misc/wget/)
#
#
# The steps are:
# 1.   Create new Git branch
# 2.   Load the dataset
# 3.   Apply Polynomial Transformation
# 4.   Train Linear Regression model
# 5.   Push changes

# %% [markdown]
# ## 1. Create new Git branch

# %% [markdown]
# **[1.1]** Create a new git branch called `adv_mla_2_poly`

# %%
# Placeholder for student's code (command line)

# %%
# Solution:
! git checkout -b adv_mla_2_poly

# %% [markdown]
# **[1.2]** Launch Jupyter Lab from your virtual environment

# %%
# Placeholder for student's code (command line)

# %%
# Solution:
! poetry run jupyter lab

# %% [markdown]
# **[1.3]** Navigate the folder `notebooks` and create a new jupyter notebook called `2_linear_poly.ipynb`

# %% [markdown]
# ## 2. Load the dataset

# %% [markdown]
# **[2.1]** Launch magic commands to automatically reload modules

# %%
# Placeholder for student's code (Python code)

# %%
# Solution
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# **[2.1]** Import the pandas, numpy packages and dump from joblib

# %%
# Placeholder for student's code (Python code)

# %%
# Solution
import pandas as pd
import numpy as np
from joblib import dump

# %% [markdown]
# **[2.2]** Import your custom function `load_sets`

# %%
# Placeholder for student's code (Python code)

# %%
# Solution
from my_krml_studentid.data.sets import load_sets

# %% [markdown]
# **[2.3]** Load the different sets from `data/processed`

# %%
# Placeholder for student's code (Python code)

# %%
# Solution
X_train, y_train, X_val, y_val, X_test, y_test = load_sets()

# %% [markdown]
# ## 3. Apply Polynomial Transformation

# %% [markdown]
# **[3.1]** Import PolynomialFeatures from sklearn.preprocessing

# %%
# Placeholder for student's code (Python code)

# %%
# Solution:
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# **[3.2]** Instantiate a PolynomialFeatures with degree 2

# %%
# Placeholder for student's code (Python code)

# %%
# Solution:
poly = PolynomialFeatures(2)

# %% [markdown]
# **[3.3]** Fit the PolynomialFeatures and perform transformation on X_train

# %%
# Placeholder for student's code (Python code)

# %%
# Solution:
X_train = poly.fit_transform(X_train)

# %% [markdown]
# **[3.4]** Display the dimensions of X_train

# %%
# Placeholder for student's code (Python code)

# %%
# Solution
X_train.shape
# Out:
# (30000, 45)

# %% [markdown]
# **[3.5]** Perform transformation on X_val and X_test with PolynomialFeatures

# %%
# Placeholder for student's code (Python code)

# %%
# Solution:
X_val = poly.transform(X_val)
X_test = poly.transform(X_test)

# %% [markdown]
# # 4. Train Linear Regression model

# %% [markdown]
# **[4.1]** Import the linear regression module from sklearn

# %%
# Placeholder for student's code (Python code)

# %%
# Solution:
from sklearn.linear_model import LinearRegression

# %% [markdown]
# **[4.2]** Task: instantiate the LinearRegression class into a variable called reg

# %%
# Placeholder for student's code (Python code)

# %%
# Solution
reg = LinearRegression()

# %% [markdown]
# **[4.3]** Task: Fit the model with the prepared data

# %%
# Placeholder for student's code (Python code)

# %%
# Solution
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **[4.4]** Import `dump` from `joblib` and save the fitted model into the folder `models` as a file called `linear_poly_2`

# %%
# Placeholder for student's code (Python code)

# %%
# Solution:
from joblib import dump

dump(reg,  '../models/linear_poly_2.joblib')
# Out:
# ['../models/linear_poly_2.joblib']

# %% [markdown]
# **[4.5]** Save the predictions from this model for the training and validation sets into 2 variables called `y_train_preds` and `y_val_preds`

# %%
# Placeholder for student's code (Python code)

# %%
# Solution:
y_train_preds = reg.predict(X_train)
y_val_preds = reg.predict(X_val)

# %% [markdown]
# **[4.6]** Import the `print_regressor_scores()` function from `my_krml_149874.

# %%
# Placeholder for student's code (Python code)

# %%
# Solution:
from my_krml_studentid.models.performance import print_regressor_scores

# %% [markdown]
# **[4.7]** Display the RMSE and MAE scores of this model on the training set

# %%
# Placeholder for student's code (Python code)

# %%
# Solution:
print_regressor_scores(y_preds=y_train_preds, y_actuals=y_train, set_name='Training')
# Out:
# RMSE Training: 6106.209286288577
# MAE Training: 4096.91039659324
# /Users/reasmeytith/Library/Caches/pypoetry/virtualenvs/adv-mla-lab-2-nK4i-H-O-py3.11/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# **[4.8]** Display the RMSE and MAE scores of this model on the validation set

# %%
# Placeholder for student's code (Python code)

# %%
# Solution:
print_regressor_scores(y_preds=y_val_preds, y_actuals=y_val, set_name='Validation')
# Out:
# RMSE Validation: 6122.877873454828
# MAE Validation: 4113.453183416502

# %% [markdown]
# **[4.9]** Display the RMSE and MAE scores of this model on the testing set

# %%
# Placeholder for student's code (Python code)

# %%
# Solution:
y_test_preds = reg.predict(X_test)
print_regressor_scores(y_preds=y_test_preds, y_actuals=y_train, set_name='Testing')
# Out:
# /Users/reasmeytith/Library/Caches/pypoetry/virtualenvs/adv-mla-lab-2-nK4i-H-O-py3.11/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 # Solution:
#       2 y_test_preds = reg.predict(X_test)
# ----> 3 print_regressor_scores(y_preds=y_test_preds, y_actuals=y_train, set_name='Testing')
#
# File ~/Library/Caches/pypoetry/virtualenvs/adv-mla-lab-2-nK4i-H-O-py3.11/lib/python3.11/site-packages/my_krml_studentid/models/performance.py:19, in print_regressor_scores(y_preds, y_actuals, set_name)
#      16 from sklearn.metrics import mean_squared_error as mse
#      17 from sklearn.metrics import mean_absolute_error as mae
# ---> 19 print(f"RMSE {set_name}: {mse(y_actuals, y_preds, squared=False)}")
#      20 print(f"MAE {set_name}: {mae(y_actuals, y_preds)}")
#
# File ~/Library/Caches/pypoetry/virtualenvs/adv-mla-lab-2-nK4i-H-O-py3.11/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/Library/Caches/pypoetry/virtualenvs/adv-mla-lab-2-nK4i-H-O-py3.11/lib/python3.11/site-packages/sklearn/metrics/_regression.py:502, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     492     warnings.warn(
#     493         (
#     494             "'squared' is deprecated in version 1.4 and "
#    (...)    499         FutureWarning,
#     500     )
#     501     if not squared:
# --> 502         return root_mean_squared_error(
#     503             y_true, y_pred, sample_weight=sample_weight, multioutput=multioutput
#     504         )
#     506 y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     507     y_true, y_pred, multioutput
#     508 )
#     509 check_consistent_length(y_true, y_pred, sample_weight)
#
# File ~/Library/Caches/pypoetry/virtualenvs/adv-mla-lab-2-nK4i-H-O-py3.11/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~/Library/Caches/pypoetry/virtualenvs/adv-mla-lab-2-nK4i-H-O-py3.11/lib/python3.11/site-packages/sklearn/metrics/_regression.py:581, in root_mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     522 @validate_params(
#     523     {
#     524         "y_true": ["array-like"],
#    (...)    532     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average"
#     533 ):
#     534     """Root mean squared error regression loss.
#     535
#     536     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)    578     0.822...
#     579     """
#     580     output_errors = np.sqrt(
# --> 581         mean_squared_error(
#     582             y_true, y_pred, sample_weight=sample_weight, multioutput="raw_values"
#     583         )
#     584     )
#     586     if isinstance(multioutput, str):
#     587         if multioutput == "raw_values":
#
# File ~/Library/Caches/pypoetry/virtualenvs/adv-mla-lab-2-nK4i-H-O-py3.11/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~/Library/Caches/pypoetry/virtualenvs/adv-mla-lab-2-nK4i-H-O-py3.11/lib/python3.11/site-packages/sklearn/metrics/_regression.py:506, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     501     if not squared:
#     502         return root_mean_squared_error(
#     503             y_true, y_pred, sample_weight=sample_weight, multioutput=multioutput
#     504         )
# --> 506 y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     507     y_true, y_pred, multioutput
#     508 )
#     509 check_consistent_length(y_true, y_pred, sample_weight)
#     510 output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~/Library/Caches/pypoetry/virtualenvs/adv-mla-lab-2-nK4i-H-O-py3.11/lib/python3.11/site-packages/sklearn/metrics/_regression.py:111, in _check_reg_targets(y_true, y_pred, multioutput, dtype, xp)
#      76 """Check that y_true and y_pred belong to the same regression task.
#      77
#      78 Parameters
#    (...)    107     correct keyword.
#     108 """
#     109 xp, _ = get_namespace(y_true, y_pred, multioutput, xp=xp)
# --> 111 check_consistent_length(y_true, y_pred)
#     112 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     113 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~/Library/Caches/pypoetry/virtualenvs/adv-mla-lab-2-nK4i-H-O-py3.11/lib/python3.11/site-packages/sklearn/utils/validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [30000, 10000]

# %% [markdown]
# # 5.   Push changes

# %% [markdown]
# **[5.1]** Add you changes to git staging area

# %%
# Placeholder for student's code (command line)

# %%
# Solution:
! git add .

# %% [markdown]
# **[5.2]** Create the snapshot of your repository and add a description

# %%
# Placeholder for student's code (command line)

# %%
# Solution:
! git commit -m "linear regression with poly 2"

# %% [markdown]
# **[5.3]** Push your snapshot to Github

# %%
# Placeholder for student's code (command line)

# %%
# Solution:
! git push -u origin adv_mla_2_poly

# %% [markdown]
# [5.4] Go to to github and merge your change to the master/main branch

# %% [markdown]
# **[5.5]** Check out to the master branch

# %%
# Placeholder for student's code (command line)

# %%
# Solution:
! git checkout master

# %% [markdown]
# **[5.6]** Pull the latest updates

# %%
# Placeholder for student's code (command line)

# %%
# Solution:
! git pull

# %% [markdown]
# **[5.7]** Stop Jupyter Lab
